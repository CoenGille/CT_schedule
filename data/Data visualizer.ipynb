# %%
import numpy as np
import pandas as pd

# %%
FMP_sorties = np.genfromtxt('FMP_sorties.csv', delimiter=',')
_svc = np.genfromtxt('svc_sorties.csv', delimiter=',')
mc_AC = np.around(_svc*.7, decimals=0)
ft = pd.read_csv('FT.csv', index_col=0, header=0).fillna('')
ft.columns = ft.columns.astype(int)

# %%
for i in FMP_sorties:
    print(i)
# Out:
# 4.0
# 0.0
# 0.0
# 4.0
# 3.0
# 3.0
# 3.0
# 4.0
# 0.0
# 0.0
# 4.0
# 4.0
# 4.0
# 3.0
# 4.0
# 0.0
# 0.0
# 5.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 4.0
# 6.0
# 4.0
# 5.0
# 3.0
# 0.0
# 0.0
# 4.0
# 6.0
# 4.0
# 5.0
# 5.0
# 0.0
# 0.0
# 4.0
# 2.0
# 5.0
# 5.0
# 3.0
# 0.0
# 0.0
# 3.0
# 4.0
# 4.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 5.0
# 6.0
# 4.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# 6.0
# 6.0
# 6.0
# 0.0
# 0.0
# 6.0
# 6.0
# ...
