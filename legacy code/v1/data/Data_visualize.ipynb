# %%
import numpy as np

# %%
no_sorties = np.genfromtxt('FMP_sorties.csv', delimiter=',')
svc = np.genfromtxt('svc_sorties.csv', delimiter=',')

# %%
a= np.around(svc*.5, decimals=0)

# %%
print(a.mean())
print(16*.5)
# Out:
# 7.745205479452054
# 8.0

# %%
print(no_sorties/a)
# Out:
# [0.25       0.         0.         0.25       0.125      0.
#  0.         0.125      0.         0.         0.125      0.
#  0.         0.125      1.375      0.         0.         1.125
#  1.25       1.375      1.25       1.5        0.         0.
#  1.375      1.375      1.5        1.5        1.375      0.
#  0.         1.5        1.85714286 1.625      1.625      1.625
#  0.         0.         1.625      1.625      1.625      1.625
#  1.625      0.         0.         1.85714286 1.85714286 1.625
#  1.625      1.625      0.         0.         1.625      1.625
#  1.625      1.625      1.625      0.         0.         1.625
#  1.625      1.625      1.625      1.625      0.         0.
#  1.85714286 1.85714286 1.85714286 1.85714286 1.85714286 0.
#  0.         1.85714286 1.85714286 1.85714286 1.625      1.625
#  0.         0.         1.625      1.625      1.625      1.625
#  1.625      0.         0.         1.625      1.625      1.625
# ...
