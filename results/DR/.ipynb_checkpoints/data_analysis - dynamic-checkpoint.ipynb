# %%
import glob

import csv
import statistics
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import pearsonr

plt.style.use(['science', 'ieee', 'no-latex'])  #pip install SciencePlots==1.0.9

# %%
def imprt():
    M = {}
    P = {}
    
    with open('C:/Users/Coen/Documents/GitHub/CT_schedule/data/missions.csv', mode='r',encoding='utf-8-sig') as f:
        reader = csv.reader(f)
        for row in reader:
            M[row[0]] = np.genfromtxt(row[1:10], dtype='int')
    
    with open('C:/Users/Coen/Documents/GitHub/CT_schedule/data/pilots.csv', mode='r',encoding='utf-8-sig') as f:
        reader = csv.reader(f)
        for row in reader:
            P[row[0]] = np.genfromtxt(row[1:6], dtype='int')
    return M, P

# %%
def read_history_live(hist):
    no_sorties = list()
    min_CT = 0 
    for p in P: 
        total_sorties_p = sum(hist[p].values())
        no_sorties.append(total_sorties_p)
        if P[p][4] > 0:
            check_min = total_sorties_p >= 41
        else:
            check_min = total_sorties_p >= 58
        count = 0
        for m in M:     
            if hist[p][m] - M[m][P[p][0]] < 0:
                count += 1
                print(f'min LIVE failed for pilot {p} on mission {m}')
        if count <= 0 and check_min:
            min_CT += 1
    des_CT = 0 
    sorties = sum([sum(hist[k].values()) for k in hist.keys()])
    for p in P:
        total_sorties_p = sum(hist[p].values())
        if P[p][4] > 0:
            check_desired = total_sorties_p >= 69
        else:
            check_desired = total_sorties_p >= 73
        count = 0
        for m in M:
            if hist[p][m] - M[m][P[p][1]] < 0:
                count += 1
                print(f'desired LIVE failed for pilot {p} on mission {m}')
        if count <= 0 and check_desired:
            des_CT += 1
    
    return min_CT, des_CT, sorties, no_sorties

# %%
def read_history_sim(hist_sim):
    no_sorties = list()
    min_CT = 0 
    for p in P: 
        total_sorties_p = sum(hist_sim[p].values())
        no_sorties.append(total_sorties_p)
        if P[p][4] > 0:
            check_min = total_sorties_p >= 37
        else:
            check_min = total_sorties_p >= 42
        count = 0
        for m in M:     
            if hist_sim[p][m] - M[m][P[p][2]] < 0:
                count += 1
                print(f'min SIM failed for pilot {p} on mission {m}')
        if count <= 0 and check_min:
            min_CT += 1
    des_CT = 0 
    sorties = sum([sum(hist_sim[k].values()) for k in hist.keys()])
    for p in P:
        total_sorties_p = sum(hist[p].values())
        if P[p][4] > 0:
            check_desired = total_sorties_p >= 53
        else:
            check_desired = total_sorties_p >= 72
        count = 0
        for m in M:
            if hist_sim[p][m] - M[m][P[p][P[p][3]]] < 0:
                count += 1
                print(f'desired SIM failed for pilot {p} on mission {m}')
        if count <= 0 and check_desired:
            des_CT += 1
    
    return min_CT, des_CT, sorties, no_sorties

# %%
M, P = imprt()

# %%
data = np.full((len(glob.glob('*CTresults_live.txt')),6), 0)
i = 0
print('live missions:')
for file in glob.glob('*CTresults_live.txt'):
    with open(file) as f:
        hist = json.load(f)
        min_CT, des_CT, sorties, no_sorties_live = read_history_live(hist)
        data[i][0] = min_CT
        data[i][1] = des_CT
        data[i][2] = sorties
        i += 1
i = 0
print('sim missions:')
for simfile in glob.glob('*CTresults_sim.txt'):
    with open(simfile) as g:
        hist_sim = json.load(g)
        min_CT, des_CT, sorties, no_sorties_sim = read_history_sim(hist_sim)
        data[i][3] = min_CT
        data[i][4] = des_CT
        data[i][5] = sorties
        i += 1
# Out:
# live missions:
# min LIVE failed for pilot Slider on mission OCA_d_4
# min LIVE failed for pilot Slider on mission OCA_n_4
# min LIVE failed for pilot Slider on mission ISR_d_2
# min LIVE failed for pilot Cougar on mission OCA_n_4
# min LIVE failed for pilot Chipper on mission SDEAD_n_4
# desired LIVE failed for pilot Iceman on mission AI_n_2
# desired LIVE failed for pilot Iceman on mission CAS_d_4
# desired LIVE failed for pilot Jester on mission ISR_d_2
# desired LIVE failed for pilot Slider on mission OCA_d_4
# desired LIVE failed for pilot Slider on mission OCA_n_4
# desired LIVE failed for pilot Slider on mission CAS_d_2
# desired LIVE failed for pilot Slider on mission ISR_d_2
# desired LIVE failed for pilot Cougar on mission OCA_n_4
# desired LIVE failed for pilot Cougar on mission DCA_n_2
# desired LIVE failed for pilot Merlin on mission AI_d_4
# desired LIVE failed for pilot Merlin on mission CAS_d_4
# desired LIVE failed for pilot Chipper on mission SDEAD_n_4
# desired LIVE failed for pilot Loggins on mission AI_n_2
# min LIVE failed for pilot Viper on mission AI_n_4
# min LIVE failed for pilot Sundown on mission OCA_d_2
# min LIVE failed for pilot Stinger on mission DCA_n_4
# min LIVE failed for pilot Jester on mission OCA_d_2
# min LIVE failed for pilot Slider on mission CAS_n_4
# min LIVE failed for pilot Kenny on mission OCA_d_4
# desired LIVE failed for pilot Viper on mission AI_n_4
# desired LIVE failed for pilot Sundown on mission OCA_d_2
# desired LIVE failed for pilot Sundown on mission CAS_n_2
# desired LIVE failed for pilot Stinger on mission DCA_n_4
# desired LIVE failed for pilot Jester on mission OCA_d_2
# desired LIVE failed for pilot Jester on mission OCA_n_2
# desired LIVE failed for pilot Jester on mission AI_n_2
# desired LIVE failed for pilot Slider on mission OCA_n_2
# desired LIVE failed for pilot Slider on mission CAS_n_4
# desired LIVE failed for pilot Charlie on mission AI_d_4
# desired LIVE failed for pilot Charlie on mission CAS_d_4
# desired LIVE failed for pilot Kenny on mission OCA_d_4
# desired LIVE failed for pilot Kenny on mission SDEAD_n_2
# desired LIVE failed for pilot Loggins on mission DCA_n_2
# desired LIVE failed for pilot Loggins on mission CAS_n_2
# desired LIVE failed for pilot Danger on mission ISR_n_2
# desired LIVE failed for pilot Zone on mission AI_d_4
# min LIVE failed for pilot Sundown on mission DCA_n_4
# min LIVE failed for pilot Slider on mission OCA_n_2
# min LIVE failed for pilot Slider on mission OCA_n_4
# min LIVE failed for pilot Slider on mission DCA_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Charlie on mission SDEAD_n_4
# min LIVE failed for pilot Kenny on mission SDEAD_n_4
# desired LIVE failed for pilot Goose on mission ISR_n_2
# desired LIVE failed for pilot Sundown on mission DCA_n_4
# desired LIVE failed for pilot Jester on mission SDEAD_d_2
# desired LIVE failed for pilot Jester on mission SDEAD_n_2
# desired LIVE failed for pilot Jester on mission DCA_d_2
# desired LIVE failed for pilot Slider on mission OCA_n_2
# desired LIVE failed for pilot Slider on mission OCA_n_4
# desired LIVE failed for pilot Slider on mission AI_n_2
# desired LIVE failed for pilot Slider on mission DCA_n_4
# desired LIVE failed for pilot Slider on mission ISR_d_2
# desired LIVE failed for pilot Slider on mission ISR_n_2
# desired LIVE failed for pilot Wolfman on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission SDEAD_n_4
# desired LIVE failed for pilot Charlie on mission ISR_n_2
# desired LIVE failed for pilot Chipper on mission AI_n_2
# desired LIVE failed for pilot Kenny on mission SDEAD_n_4
# desired LIVE failed for pilot Danger on mission AI_n_2
# min LIVE failed for pilot Maverick on mission OCA_n_4
# min LIVE failed for pilot Jester on mission SDEAD_n_4
# min LIVE failed for pilot Cougar on mission OCA_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Chipper on mission OCA_n_4
# min LIVE failed for pilot Chipper on mission DCA_n_4
# min LIVE failed for pilot Kenny on mission SDEAD_n_4
# min LIVE failed for pilot Loggins on mission DCA_n_4
# desired LIVE failed for pilot Maverick on mission OCA_n_4
# desired LIVE failed for pilot Iceman on mission ISR_n_2
# desired LIVE failed for pilot Viper on mission DCA_n_2
# desired LIVE failed for pilot Jester on mission SDEAD_d_2
# desired LIVE failed for pilot Jester on mission SDEAD_d_4
# desired LIVE failed for pilot Jester on mission SDEAD_n_4
# desired LIVE failed for pilot Jester on mission AI_d_2
# desired LIVE failed for pilot Jester on mission AI_n_2
# desired LIVE failed for pilot Slider on mission SDEAD_n_2
# desired LIVE failed for pilot Slider on mission CAS_d_2
# desired LIVE failed for pilot Slider on mission ISR_d_2
# desired LIVE failed for pilot Cougar on mission OCA_n_4
# desired LIVE failed for pilot Wolfman on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission SDEAD_d_2
# desired LIVE failed for pilot Charlie on mission DCA_d_4
# desired LIVE failed for pilot Chipper on mission OCA_n_4
# desired LIVE failed for pilot Chipper on mission DCA_d_2
# desired LIVE failed for pilot Chipper on mission DCA_n_4
# desired LIVE failed for pilot Chipper on mission CAS_n_2
# desired LIVE failed for pilot Kenny on mission SDEAD_n_4
# desired LIVE failed for pilot Loggins on mission DCA_n_4
# min LIVE failed for pilot Sundown on mission OCA_d_2
# min LIVE failed for pilot Sundown on mission SDEAD_n_2
# min LIVE failed for pilot Sundown on mission CAS_n_2
# min LIVE failed for pilot Sundown on mission CAS_n_4
# min LIVE failed for pilot Slider on mission OCA_d_2
# min LIVE failed for pilot Chipper on mission OCA_d_2
# min LIVE failed for pilot Kenny on mission OCA_d_4
# min LIVE failed for pilot Loggins on mission AI_d_4
# min LIVE failed for pilot Loggins on mission DCA_n_4
# min LIVE failed for pilot Zone on mission CAS_n_4
# desired LIVE failed for pilot Viper on mission CAS_d_2
# desired LIVE failed for pilot Sundown on mission OCA_d_2
# desired LIVE failed for pilot Sundown on mission OCA_n_2
# desired LIVE failed for pilot Sundown on mission SDEAD_d_4
# desired LIVE failed for pilot Sundown on mission SDEAD_n_2
# desired LIVE failed for pilot Sundown on mission AI_n_2
# desired LIVE failed for pilot Sundown on mission DCA_n_2
# desired LIVE failed for pilot Sundown on mission CAS_d_2
# desired LIVE failed for pilot Sundown on mission CAS_d_4
# desired LIVE failed for pilot Sundown on mission CAS_n_2
# desired LIVE failed for pilot Sundown on mission CAS_n_4
# desired LIVE failed for pilot Slider on mission OCA_d_2
# desired LIVE failed for pilot Charlie on mission DCA_d_4
# desired LIVE failed for pilot Chipper on mission OCA_d_2
# desired LIVE failed for pilot Kenny on mission OCA_d_4
# desired LIVE failed for pilot Kenny on mission SDEAD_d_4
# desired LIVE failed for pilot Kenny on mission CAS_d_4
# desired LIVE failed for pilot Loggins on mission SDEAD_d_2
# desired LIVE failed for pilot Loggins on mission AI_d_4
# desired LIVE failed for pilot Loggins on mission DCA_n_4
# desired LIVE failed for pilot Loggins on mission ISR_d_2
# desired LIVE failed for pilot Zone on mission CAS_n_4
# min LIVE failed for pilot Jester on mission DCA_d_2
# min LIVE failed for pilot Charlie on mission CAS_n_4
# desired LIVE failed for pilot Goose on mission DCA_n_2
# desired LIVE failed for pilot Sundown on mission DCA_n_2
# desired LIVE failed for pilot Jester on mission DCA_d_2
# desired LIVE failed for pilot Jester on mission CAS_n_2
# desired LIVE failed for pilot Jester on mission ISR_d_2
# desired LIVE failed for pilot Charlie on mission AI_d_4
# desired LIVE failed for pilot Charlie on mission DCA_d_4
# desired LIVE failed for pilot Charlie on mission CAS_n_4
# desired LIVE failed for pilot Chipper on mission AI_d_2
# desired LIVE failed for pilot Chipper on mission CAS_n_2
# desired LIVE failed for pilot Loggins on mission CAS_n_2
# min LIVE failed for pilot Viper on mission OCA_n_4
# min LIVE failed for pilot Sundown on mission OCA_d_2
# min LIVE failed for pilot Sundown on mission OCA_d_4
# min LIVE failed for pilot Jester on mission CAS_n_4
# min LIVE failed for pilot Slider on mission OCA_d_4
# min LIVE failed for pilot Slider on mission CAS_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Charlie on mission CAS_n_4
# min LIVE failed for pilot Danger on mission CAS_n_4
# desired LIVE failed for pilot Iceman on mission DCA_n_2
# desired LIVE failed for pilot Viper on mission OCA_d_4
# desired LIVE failed for pilot Viper on mission OCA_n_4
# desired LIVE failed for pilot Sundown on mission OCA_d_2
# desired LIVE failed for pilot Sundown on mission OCA_d_4
# desired LIVE failed for pilot Sundown on mission SDEAD_d_2
# desired LIVE failed for pilot Stinger on mission ISR_n_2
# desired LIVE failed for pilot Jester on mission SDEAD_n_2
# desired LIVE failed for pilot Jester on mission AI_d_2
# desired LIVE failed for pilot Jester on mission CAS_n_2
# desired LIVE failed for pilot Jester on mission CAS_n_4
# desired LIVE failed for pilot Slider on mission OCA_d_4
# desired LIVE failed for pilot Slider on mission SDEAD_n_2
# desired LIVE failed for pilot Slider on mission AI_d_2
# desired LIVE failed for pilot Slider on mission CAS_n_4
# desired LIVE failed for pilot Slider on mission ISR_n_2
# desired LIVE failed for pilot Wolfman on mission ISR_n_2
# desired LIVE failed for pilot Merlin on mission ISR_n_2
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission SDEAD_n_2
# desired LIVE failed for pilot Charlie on mission AI_n_2
# desired LIVE failed for pilot Charlie on mission CAS_n_4
# desired LIVE failed for pilot Charlie on mission ISR_n_2
# desired LIVE failed for pilot Chipper on mission SDEAD_d_2
# desired LIVE failed for pilot Chipper on mission SDEAD_n_2
# desired LIVE failed for pilot Loggins on mission CAS_n_2
# desired LIVE failed for pilot Danger on mission SDEAD_n_2
# desired LIVE failed for pilot Danger on mission AI_n_2
# desired LIVE failed for pilot Danger on mission CAS_n_4
# desired LIVE failed for pilot Zone on mission SDEAD_d_4
# desired LIVE failed for pilot Zone on mission AI_n_2
# min LIVE failed for pilot Maverick on mission DCA_d_4
# min LIVE failed for pilot Sundown on mission CAS_n_4
# min LIVE failed for pilot Stinger on mission SDEAD_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Charlie on mission SDEAD_n_4
# min LIVE failed for pilot Charlie on mission AI_n_4
# min LIVE failed for pilot Charlie on mission DCA_n_4
# desired LIVE failed for pilot Maverick on mission DCA_d_4
# desired LIVE failed for pilot Sundown on mission CAS_n_4
# desired LIVE failed for pilot Stinger on mission SDEAD_n_4
# desired LIVE failed for pilot Jester on mission CAS_d_2
# desired LIVE failed for pilot Jester on mission CAS_n_2
# desired LIVE failed for pilot Jester on mission ISR_d_2
# desired LIVE failed for pilot Slider on mission AI_d_4
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission SDEAD_n_4
# desired LIVE failed for pilot Charlie on mission AI_n_4
# desired LIVE failed for pilot Charlie on mission DCA_n_4
# desired LIVE failed for pilot Chipper on mission OCA_n_2
# desired LIVE failed for pilot Chipper on mission DCA_d_4
# desired LIVE failed for pilot Danger on mission AI_d_2
# min LIVE failed for pilot Maverick on mission CAS_n_4
# min LIVE failed for pilot Sundown on mission DCA_n_4
# min LIVE failed for pilot Stinger on mission SDEAD_n_4
# min LIVE failed for pilot Jester on mission DCA_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Chipper on mission SDEAD_n_4
# min LIVE failed for pilot Chipper on mission CAS_n_4
# desired LIVE failed for pilot Maverick on mission CAS_n_4
# desired LIVE failed for pilot Iceman on mission DCA_n_2
# desired LIVE failed for pilot Sundown on mission DCA_n_4
# desired LIVE failed for pilot Stinger on mission SDEAD_n_4
# desired LIVE failed for pilot Jester on mission DCA_n_4
# desired LIVE failed for pilot Slider on mission CAS_n_2
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission SDEAD_d_2
# desired LIVE failed for pilot Chipper on mission SDEAD_d_2
# desired LIVE failed for pilot Chipper on mission SDEAD_n_4
# desired LIVE failed for pilot Chipper on mission CAS_n_2
# desired LIVE failed for pilot Chipper on mission CAS_n_4
# desired LIVE failed for pilot Zone on mission CAS_n_2
# min LIVE failed for pilot Sundown on mission OCA_d_2
# min LIVE failed for pilot Sundown on mission OCA_n_4
# min LIVE failed for pilot Sundown on mission SDEAD_n_4
# min LIVE failed for pilot Sundown on mission AI_d_2
# min LIVE failed for pilot Stinger on mission OCA_n_4
# min LIVE failed for pilot Stinger on mission DCA_n_4
# min LIVE failed for pilot Slider on mission OCA_d_4
# min LIVE failed for pilot Slider on mission CAS_n_4
# min LIVE failed for pilot Chipper on mission SDEAD_n_4
# min LIVE failed for pilot Loggins on mission CAS_n_4
# min LIVE failed for pilot Zone on mission SDEAD_n_4
# desired LIVE failed for pilot Maverick on mission CAS_d_4
# desired LIVE failed for pilot Sundown on mission OCA_d_2
# desired LIVE failed for pilot Sundown on mission OCA_n_4
# desired LIVE failed for pilot Sundown on mission SDEAD_n_4
# desired LIVE failed for pilot Sundown on mission AI_d_2
# desired LIVE failed for pilot Stinger on mission OCA_n_4
# desired LIVE failed for pilot Stinger on mission DCA_n_4
# desired LIVE failed for pilot Slider on mission OCA_d_4
# desired LIVE failed for pilot Slider on mission CAS_n_4
# desired LIVE failed for pilot Wolfman on mission CAS_n_2
# desired LIVE failed for pilot Charlie on mission DCA_d_4
# desired LIVE failed for pilot Chipper on mission SDEAD_n_4
# desired LIVE failed for pilot Loggins on mission AI_d_4
# desired LIVE failed for pilot Loggins on mission CAS_n_4
# desired LIVE failed for pilot Zone on mission SDEAD_n_4
# min LIVE failed for pilot Sundown on mission OCA_d_4
# min LIVE failed for pilot Jester on mission SDEAD_n_4
# min LIVE failed for pilot Jester on mission AI_n_4
# min LIVE failed for pilot Hollywood on mission SDEAD_n_4
# min LIVE failed for pilot Charlie on mission DCA_n_4
# min LIVE failed for pilot Chipper on mission SDEAD_d_2
# min LIVE failed for pilot Chipper on mission DCA_n_4
# min LIVE failed for pilot Kenny on mission OCA_d_4
# min LIVE failed for pilot Kenny on mission OCA_n_4
# min LIVE failed for pilot Loggins on mission OCA_n_4
# desired LIVE failed for pilot Maverick on mission SDEAD_n_2
# desired LIVE failed for pilot Sundown on mission OCA_d_4
# desired LIVE failed for pilot Sundown on mission OCA_n_2
# desired LIVE failed for pilot Sundown on mission DCA_d_2
# desired LIVE failed for pilot Sundown on mission CAS_n_2
# desired LIVE failed for pilot Stinger on mission CAS_d_2
# desired LIVE failed for pilot Stinger on mission ISR_d_2
# desired LIVE failed for pilot Jester on mission SDEAD_n_4
# desired LIVE failed for pilot Jester on mission AI_n_4
# desired LIVE failed for pilot Jester on mission ISR_d_2
# desired LIVE failed for pilot Slider on mission SDEAD_n_2
# desired LIVE failed for pilot Slider on mission CAS_d_2
# desired LIVE failed for pilot Hollywood on mission SDEAD_n_4
# desired LIVE failed for pilot Cougar on mission DCA_n_2
# desired LIVE failed for pilot Cougar on mission CAS_n_2
# desired LIVE failed for pilot Charlie on mission AI_n_2
# desired LIVE failed for pilot Charlie on mission DCA_n_4
# desired LIVE failed for pilot Charlie on mission CAS_n_2
# desired LIVE failed for pilot Chipper on mission SDEAD_d_2
# desired LIVE failed for pilot Chipper on mission DCA_n_4
# desired LIVE failed for pilot Chipper on mission CAS_d_2
# desired LIVE failed for pilot Kenny on mission OCA_d_4
# desired LIVE failed for pilot Kenny on mission OCA_n_4
# desired LIVE failed for pilot Loggins on mission OCA_n_4
# desired LIVE failed for pilot Loggins on mission DCA_n_2
# desired LIVE failed for pilot Danger on mission AI_n_2
# min LIVE failed for pilot Wolfman on mission DCA_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Kenny on mission DCA_n_4
# desired LIVE failed for pilot Maverick on mission DCA_d_4
# desired LIVE failed for pilot Goose on mission AI_n_2
# desired LIVE failed for pilot Goose on mission CAS_n_2
# desired LIVE failed for pilot Sundown on mission OCA_n_2
# desired LIVE failed for pilot Jester on mission DCA_n_2
# desired LIVE failed for pilot Slider on mission DCA_d_4
# desired LIVE failed for pilot Slider on mission CAS_d_4
# desired LIVE failed for pilot Cougar on mission CAS_d_2
# desired LIVE failed for pilot Wolfman on mission DCA_n_4
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission AI_n_2
# desired LIVE failed for pilot Chipper on mission OCA_n_2
# desired LIVE failed for pilot Kenny on mission DCA_n_4
# desired LIVE failed for pilot Loggins on mission CAS_d_4
# desired LIVE failed for pilot Zone on mission CAS_d_2
# min LIVE failed for pilot Sundown on mission CAS_n_4
# min LIVE failed for pilot Slider on mission OCA_d_4
# min LIVE failed for pilot Slider on mission OCA_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Charlie on mission AI_n_4
# min LIVE failed for pilot Charlie on mission CAS_n_4
# min LIVE failed for pilot Chipper on mission OCA_n_4
# min LIVE failed for pilot Chipper on mission AI_n_4
# min LIVE failed for pilot Chipper on mission CAS_d_2
# min LIVE failed for pilot Chipper on mission ISR_d_2
# min LIVE failed for pilot Zone on mission CAS_n_4
# desired LIVE failed for pilot Sundown on mission CAS_n_4
# desired LIVE failed for pilot Stinger on mission SDEAD_d_4
# desired LIVE failed for pilot Stinger on mission ISR_n_2
# desired LIVE failed for pilot Jester on mission SDEAD_d_2
# desired LIVE failed for pilot Jester on mission ISR_n_2
# desired LIVE failed for pilot Slider on mission OCA_d_4
# desired LIVE failed for pilot Slider on mission OCA_n_4
# desired LIVE failed for pilot Wolfman on mission DCA_d_4
# desired LIVE failed for pilot Merlin on mission DCA_n_2
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission AI_n_4
# desired LIVE failed for pilot Charlie on mission DCA_d_4
# desired LIVE failed for pilot Charlie on mission CAS_n_4
# desired LIVE failed for pilot Chipper on mission OCA_n_4
# desired LIVE failed for pilot Chipper on mission SDEAD_n_2
# desired LIVE failed for pilot Chipper on mission AI_n_4
# desired LIVE failed for pilot Chipper on mission DCA_d_2
# desired LIVE failed for pilot Chipper on mission CAS_d_2
# desired LIVE failed for pilot Chipper on mission ISR_d_2
# desired LIVE failed for pilot Zone on mission CAS_n_4
# min LIVE failed for pilot Sundown on mission SDEAD_n_4
# min LIVE failed for pilot Sundown on mission CAS_n_4
# min LIVE failed for pilot Slider on mission OCA_d_4
# min LIVE failed for pilot Loggins on mission SDEAD_n_4
# min LIVE failed for pilot Loggins on mission CAS_n_4
# desired LIVE failed for pilot Maverick on mission SDEAD_n_2
# desired LIVE failed for pilot Iceman on mission OCA_n_2
# desired LIVE failed for pilot Iceman on mission AI_n_2
# desired LIVE failed for pilot Viper on mission CAS_n_2
# desired LIVE failed for pilot Sundown on mission SDEAD_n_4
# desired LIVE failed for pilot Sundown on mission CAS_n_4
# desired LIVE failed for pilot Stinger on mission AI_n_2
# desired LIVE failed for pilot Jester on mission OCA_n_2
# desired LIVE failed for pilot Jester on mission CAS_n_2
# desired LIVE failed for pilot Slider on mission OCA_d_4
# desired LIVE failed for pilot Slider on mission AI_n_2
# desired LIVE failed for pilot Slider on mission ISR_n_2
# desired LIVE failed for pilot Cougar on mission DCA_n_2
# desired LIVE failed for pilot Merlin on mission DCA_d_2
# desired LIVE failed for pilot Charlie on mission SDEAD_n_2
# desired LIVE failed for pilot Charlie on mission AI_n_2
# desired LIVE failed for pilot Chipper on mission SDEAD_n_2
# desired LIVE failed for pilot Kenny on mission CAS_n_2
# desired LIVE failed for pilot Loggins on mission OCA_n_2
# desired LIVE failed for pilot Loggins on mission SDEAD_n_2
# desired LIVE failed for pilot Loggins on mission SDEAD_n_4
# desired LIVE failed for pilot Loggins on mission DCA_n_2
# desired LIVE failed for pilot Loggins on mission CAS_n_4
# desired LIVE failed for pilot Danger on mission AI_n_2
# min LIVE failed for pilot Sundown on mission CAS_n_4
# min LIVE failed for pilot Jester on mission CAS_n_4
# min LIVE failed for pilot Cougar on mission AI_n_4
# min LIVE failed for pilot Chipper on mission CAS_n_4
# min LIVE failed for pilot Kenny on mission CAS_n_4
# min LIVE failed for pilot Loggins on mission OCA_n_4
# min LIVE failed for pilot Loggins on mission SDEAD_n_4
# desired LIVE failed for pilot Goose on mission SDEAD_d_4
# desired LIVE failed for pilot Sundown on mission CAS_n_4
# desired LIVE failed for pilot Stinger on mission CAS_d_2
# desired LIVE failed for pilot Jester on mission CAS_n_4
# desired LIVE failed for pilot Slider on mission SDEAD_d_2
# desired LIVE failed for pilot Slider on mission DCA_d_4
# desired LIVE failed for pilot Slider on mission CAS_d_2
# desired LIVE failed for pilot Slider on mission CAS_n_2
# desired LIVE failed for pilot Hollywood on mission SDEAD_n_2
# desired LIVE failed for pilot Cougar on mission AI_n_4
# desired LIVE failed for pilot Chipper on mission CAS_d_2
# desired LIVE failed for pilot Chipper on mission CAS_n_4
# desired LIVE failed for pilot Kenny on mission SDEAD_d_4
# desired LIVE failed for pilot Kenny on mission AI_n_2
# desired LIVE failed for pilot Kenny on mission DCA_n_2
# desired LIVE failed for pilot Kenny on mission CAS_n_4
# desired LIVE failed for pilot Loggins on mission OCA_n_4
# desired LIVE failed for pilot Loggins on mission SDEAD_n_4
# min LIVE failed for pilot Sundown on mission SDEAD_n_4
# min LIVE failed for pilot Sundown on mission DCA_n_4
# min LIVE failed for pilot Merlin on mission DCA_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Charlie on mission DCA_n_4
# min LIVE failed for pilot Chipper on mission OCA_d_4
# min LIVE failed for pilot Kenny on mission SDEAD_n_4
# desired LIVE failed for pilot Goose on mission SDEAD_d_4
# desired LIVE failed for pilot Sundown on mission SDEAD_n_4
# desired LIVE failed for pilot Sundown on mission DCA_n_2
# desired LIVE failed for pilot Sundown on mission DCA_n_4
# desired LIVE failed for pilot Merlin on mission DCA_n_4
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission SDEAD_d_2
# desired LIVE failed for pilot Charlie on mission SDEAD_n_2
# desired LIVE failed for pilot Charlie on mission AI_d_4
# desired LIVE failed for pilot Charlie on mission DCA_d_4
# desired LIVE failed for pilot Charlie on mission DCA_n_4
# desired LIVE failed for pilot Chipper on mission OCA_d_4
# desired LIVE failed for pilot Chipper on mission DCA_d_2
# desired LIVE failed for pilot Kenny on mission SDEAD_n_4
# desired LIVE failed for pilot Kenny on mission CAS_d_4
# desired LIVE failed for pilot Danger on mission AI_d_4
# min LIVE failed for pilot Kenny on mission CAS_n_4
# min LIVE failed for pilot Loggins on mission OCA_d_2
# min LIVE failed for pilot Loggins on mission CAS_n_4
# min LIVE failed for pilot Zone on mission AI_n_4
# desired LIVE failed for pilot Maverick on mission DCA_d_4
# desired LIVE failed for pilot Stinger on mission ISR_n_2
# desired LIVE failed for pilot Slider on mission DCA_d_4
# desired LIVE failed for pilot Charlie on mission AI_n_2
# desired LIVE failed for pilot Kenny on mission SDEAD_d_2
# desired LIVE failed for pilot Kenny on mission CAS_n_4
# desired LIVE failed for pilot Loggins on mission OCA_d_2
# desired LIVE failed for pilot Loggins on mission AI_d_4
# desired LIVE failed for pilot Loggins on mission CAS_n_4
# desired LIVE failed for pilot Zone on mission AI_n_4
# min LIVE failed for pilot Slider on mission OCA_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Kenny on mission DCA_n_4
# min LIVE failed for pilot Loggins on mission DCA_n_4
# desired LIVE failed for pilot Maverick on mission SDEAD_n_2
# desired LIVE failed for pilot Sundown on mission AI_d_4
# desired LIVE failed for pilot Sundown on mission CAS_d_4
# desired LIVE failed for pilot Stinger on mission CAS_d_4
# desired LIVE failed for pilot Slider on mission OCA_n_2
# desired LIVE failed for pilot Slider on mission OCA_n_4
# desired LIVE failed for pilot Wolfman on mission AI_n_2
# desired LIVE failed for pilot Wolfman on mission CAS_d_4
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission SDEAD_d_2
# desired LIVE failed for pilot Charlie on mission AI_d_2
# desired LIVE failed for pilot Charlie on mission DCA_d_4
# desired LIVE failed for pilot Charlie on mission CAS_d_4
# desired LIVE failed for pilot Kenny on mission DCA_n_4
# desired LIVE failed for pilot Loggins on mission DCA_n_4
# min LIVE failed for pilot Jester on mission DCA_n_4
# min LIVE failed for pilot Merlin on mission OCA_n_4
# min LIVE failed for pilot Chipper on mission SDEAD_n_4
# min LIVE failed for pilot Chipper on mission DCA_n_4
# min LIVE failed for pilot Chipper on mission CAS_n_4
# desired LIVE failed for pilot Maverick on mission CAS_n_2
# desired LIVE failed for pilot Maverick on mission ISR_n_2
# desired LIVE failed for pilot Iceman on mission AI_n_2
# desired LIVE failed for pilot Iceman on mission CAS_d_2
# desired LIVE failed for pilot Sundown on mission ISR_n_2
# desired LIVE failed for pilot Jester on mission OCA_n_2
# desired LIVE failed for pilot Jester on mission DCA_n_4
# desired LIVE failed for pilot Merlin on mission OCA_n_4
# desired LIVE failed for pilot Merlin on mission DCA_d_2
# desired LIVE failed for pilot Merlin on mission CAS_d_4
# desired LIVE failed for pilot Charlie on mission OCA_n_2
# desired LIVE failed for pilot Charlie on mission SDEAD_d_4
# desired LIVE failed for pilot Charlie on mission DCA_d_4
# desired LIVE failed for pilot Chipper on mission SDEAD_n_4
# desired LIVE failed for pilot Chipper on mission DCA_n_4
# desired LIVE failed for pilot Chipper on mission CAS_n_4
# desired LIVE failed for pilot Chipper on mission ISR_n_2
# desired LIVE failed for pilot Loggins on mission ISR_n_2
# min LIVE failed for pilot Sundown on mission OCA_d_2
# min LIVE failed for pilot Sundown on mission DCA_n_4
# min LIVE failed for pilot Cougar on mission AI_n_4
# min LIVE failed for pilot Zone on mission DCA_n_4
# desired LIVE failed for pilot Iceman on mission CAS_d_2
# desired LIVE failed for pilot Iceman on mission CAS_n_2
# desired LIVE failed for pilot Viper on mission SDEAD_n_2
# desired LIVE failed for pilot Sundown on mission OCA_d_2
# desired LIVE failed for pilot Sundown on mission DCA_n_4
# desired LIVE failed for pilot Sundown on mission CAS_d_4
# desired LIVE failed for pilot Sundown on mission CAS_n_2
# desired LIVE failed for pilot Cougar on mission AI_n_4
# desired LIVE failed for pilot Kenny on mission OCA_n_2
# desired LIVE failed for pilot Kenny on mission DCA_n_2
# desired LIVE failed for pilot Loggins on mission AI_d_4
# desired LIVE failed for pilot Danger on mission AI_d_2
# desired LIVE failed for pilot Zone on mission DCA_n_4
# min LIVE failed for pilot Sundown on mission OCA_d_4
# min LIVE failed for pilot Sundown on mission CAS_n_4
# min LIVE failed for pilot Jester on mission OCA_n_4
# min LIVE failed for pilot Wolfman on mission AI_n_4
# min LIVE failed for pilot Merlin on mission OCA_n_4
# min LIVE failed for pilot Kenny on mission CAS_n_4
# desired LIVE failed for pilot Iceman on mission ISR_n_2
# desired LIVE failed for pilot Sundown on mission OCA_d_4
# desired LIVE failed for pilot Sundown on mission CAS_n_4
# desired LIVE failed for pilot Stinger on mission SDEAD_d_4
# desired LIVE failed for pilot Jester on mission OCA_n_4
# desired LIVE failed for pilot Jester on mission CAS_d_4
# desired LIVE failed for pilot Hollywood on mission SDEAD_n_2
# desired LIVE failed for pilot Wolfman on mission OCA_n_2
# desired LIVE failed for pilot Wolfman on mission AI_n_2
# desired LIVE failed for pilot Wolfman on mission AI_n_4
# desired LIVE failed for pilot Merlin on mission OCA_n_4
# desired LIVE failed for pilot Chipper on mission SDEAD_d_2
# desired LIVE failed for pilot Kenny on mission CAS_n_4
# min LIVE failed for pilot Slider on mission OCA_d_2
# min LIVE failed for pilot Chipper on mission OCA_d_4
# min LIVE failed for pilot Chipper on mission DCA_n_4
# min LIVE failed for pilot Kenny on mission OCA_d_4
# min LIVE failed for pilot Kenny on mission DCA_n_4
# desired LIVE failed for pilot Slider on mission OCA_d_2
# desired LIVE failed for pilot Slider on mission OCA_n_2
# desired LIVE failed for pilot Cougar on mission OCA_n_2
# desired LIVE failed for pilot Chipper on mission OCA_d_4
# desired LIVE failed for pilot Chipper on mission SDEAD_d_2
# desired LIVE failed for pilot Chipper on mission SDEAD_d_4
# desired LIVE failed for pilot Chipper on mission DCA_n_4
# desired LIVE failed for pilot Kenny on mission OCA_d_4
# desired LIVE failed for pilot Kenny on mission DCA_n_4
# desired LIVE failed for pilot Loggins on mission ISR_d_2
# desired LIVE failed for pilot Danger on mission ISR_n_2
# min LIVE failed for pilot Goose on mission SDEAD_n_4
# min LIVE failed for pilot Stinger on mission DCA_d_4
# min LIVE failed for pilot Slider on mission OCA_d_4
# min LIVE failed for pilot Chipper on mission AI_n_4
# min LIVE failed for pilot Loggins on mission CAS_n_4
# desired LIVE failed for pilot Maverick on mission DCA_d_4
# desired LIVE failed for pilot Iceman on mission DCA_n_2
# desired LIVE failed for pilot Viper on mission OCA_n_2
# desired LIVE failed for pilot Goose on mission OCA_n_2
# desired LIVE failed for pilot Goose on mission SDEAD_n_4
# desired LIVE failed for pilot Sundown on mission DCA_n_2
# desired LIVE failed for pilot Stinger on mission SDEAD_d_4
# desired LIVE failed for pilot Stinger on mission DCA_d_4
# desired LIVE failed for pilot Jester on mission SDEAD_n_2
# desired LIVE failed for pilot Jester on mission AI_n_2
# desired LIVE failed for pilot Jester on mission DCA_d_2
# desired LIVE failed for pilot Slider on mission OCA_d_4
# desired LIVE failed for pilot Slider on mission DCA_n_2
# desired LIVE failed for pilot Wolfman on mission OCA_n_2
# desired LIVE failed for pilot Charlie on mission SDEAD_d_4
# desired LIVE failed for pilot Charlie on mission DCA_d_4
# desired LIVE failed for pilot Chipper on mission SDEAD_n_2
# desired LIVE failed for pilot Chipper on mission AI_n_4
# desired LIVE failed for pilot Chipper on mission DCA_d_2
# desired LIVE failed for pilot Chipper on mission CAS_d_4
# desired LIVE failed for pilot Kenny on mission OCA_n_2
# desired LIVE failed for pilot Kenny on mission SDEAD_d_2
# desired LIVE failed for pilot Loggins on mission CAS_n_4
# min LIVE failed for pilot Sundown on mission DCA_n_2
# min LIVE failed for pilot Stinger on mission SDEAD_n_4
# min LIVE failed for pilot Kenny on mission OCA_n_4
# min LIVE failed for pilot Kenny on mission DCA_n_4
# min LIVE failed for pilot Danger on mission SDEAD_n_4
# desired LIVE failed for pilot Maverick on mission AI_n_2
# desired LIVE failed for pilot Maverick on mission CAS_n_2
# desired LIVE failed for pilot Sundown on mission DCA_n_2
# desired LIVE failed for pilot Stinger on mission SDEAD_n_4
# desired LIVE failed for pilot Jester on mission CAS_n_2
# desired LIVE failed for pilot Hollywood on mission ISR_n_2
# desired LIVE failed for pilot Wolfman on mission OCA_n_2
# desired LIVE failed for pilot Chipper on mission ISR_d_2
# desired LIVE failed for pilot Chipper on mission ISR_n_2
# desired LIVE failed for pilot Kenny on mission OCA_n_2
# desired LIVE failed for pilot Kenny on mission OCA_n_4
# desired LIVE failed for pilot Kenny on mission AI_n_2
# desired LIVE failed for pilot Kenny on mission DCA_n_4
# desired LIVE failed for pilot Loggins on mission AI_d_4
# desired LIVE failed for pilot Loggins on mission CAS_n_2
# desired LIVE failed for pilot Danger on mission SDEAD_n_4
# min LIVE failed for pilot Sundown on mission OCA_d_2
# min LIVE failed for pilot Sundown on mission OCA_n_4
# min LIVE failed for pilot Stinger on mission SDEAD_n_4
# min LIVE failed for pilot Cougar on mission DCA_n_4
# min LIVE failed for pilot Charlie on mission DCA_n_4
# min LIVE failed for pilot Charlie on mission CAS_n_4
# min LIVE failed for pilot Chipper on mission SDEAD_n_4
# min LIVE failed for pilot Chipper on mission CAS_n_4
# min LIVE failed for pilot Loggins on mission DCA_n_4
# desired LIVE failed for pilot Maverick on mission CAS_d_4
# desired LIVE failed for pilot Viper on mission SDEAD_n_2
# desired LIVE failed for pilot Sundown on mission OCA_d_2
# desired LIVE failed for pilot Sundown on mission OCA_n_4
# desired LIVE failed for pilot Sundown on mission CAS_n_2
# desired LIVE failed for pilot Sundown on mission ISR_n_2
# desired LIVE failed for pilot Stinger on mission SDEAD_n_4
# desired LIVE failed for pilot Stinger on mission DCA_d_4
# desired LIVE failed for pilot Jester on mission ISR_n_2
# desired LIVE failed for pilot Slider on mission ISR_d_2
# desired LIVE failed for pilot Slider on mission ISR_n_2
# desired LIVE failed for pilot Cougar on mission DCA_n_4
# desired LIVE failed for pilot Charlie on mission DCA_n_4
# desired LIVE failed for pilot Charlie on mission CAS_n_4
# desired LIVE failed for pilot Chipper on mission SDEAD_d_2
# desired LIVE failed for pilot Chipper on mission SDEAD_n_4
# desired LIVE failed for pilot Chipper on mission CAS_d_2
# desired LIVE failed for pilot Chipper on mission CAS_n_4
# desired LIVE failed for pilot Loggins on mission DCA_n_2
# desired LIVE failed for pilot Loggins on mission DCA_n_4
# min LIVE failed for pilot Viper on mission CAS_n_4
# min LIVE failed for pilot Sundown on mission OCA_d_4
# min LIVE failed for pilot Jester on mission SDEAD_n_4
# min LIVE failed for pilot Jester on mission CAS_n_4
# min LIVE failed for pilot Slider on mission OCA_d_2
# min LIVE failed for pilot Slider on mission OCA_d_4
# min LIVE failed for pilot Cougar on mission CAS_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Charlie on mission AI_d_2
# min LIVE failed for pilot Kenny on mission CAS_n_4
# desired LIVE failed for pilot Maverick on mission CAS_n_2
# desired LIVE failed for pilot Viper on mission CAS_n_4
# desired LIVE failed for pilot Sundown on mission OCA_d_4
# desired LIVE failed for pilot Jester on mission SDEAD_n_4
# desired LIVE failed for pilot Jester on mission AI_d_2
# desired LIVE failed for pilot Jester on mission CAS_d_4
# desired LIVE failed for pilot Jester on mission CAS_n_4
# desired LIVE failed for pilot Jester on mission ISR_d_2
# desired LIVE failed for pilot Slider on mission OCA_d_2
# desired LIVE failed for pilot Slider on mission OCA_d_4
# desired LIVE failed for pilot Slider on mission CAS_d_4
# desired LIVE failed for pilot Cougar on mission CAS_n_4
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission OCA_n_2
# desired LIVE failed for pilot Charlie on mission SDEAD_n_2
# desired LIVE failed for pilot Charlie on mission AI_d_2
# desired LIVE failed for pilot Charlie on mission DCA_d_2
# desired LIVE failed for pilot Chipper on mission CAS_n_2
# desired LIVE failed for pilot Kenny on mission CAS_n_4
# desired LIVE failed for pilot Zone on mission SDEAD_n_2
# min LIVE failed for pilot Stinger on mission SDEAD_n_4
# min LIVE failed for pilot Stinger on mission DCA_n_4
# min LIVE failed for pilot Jester on mission AI_d_4
# min LIVE failed for pilot Jester on mission AI_n_4
# min LIVE failed for pilot Slider on mission OCA_n_4
# min LIVE failed for pilot Cougar on mission OCA_n_4
# min LIVE failed for pilot Charlie on mission OCA_d_4
# min LIVE failed for pilot Charlie on mission DCA_n_4
# min LIVE failed for pilot Chipper on mission OCA_d_2
# min LIVE failed for pilot Chipper on mission SDEAD_n_4
# min LIVE failed for pilot Chipper on mission DCA_d_2
# min LIVE failed for pilot Kenny on mission OCA_d_2
# min LIVE failed for pilot Kenny on mission OCA_d_4
# min LIVE failed for pilot Kenny on mission AI_d_2
# min LIVE failed for pilot Kenny on mission CAS_d_4
# desired LIVE failed for pilot Goose on mission DCA_n_2
# desired LIVE failed for pilot Sundown on mission AI_n_2
# desired LIVE failed for pilot Stinger on mission SDEAD_n_2
# desired LIVE failed for pilot Stinger on mission SDEAD_n_4
# desired LIVE failed for pilot Stinger on mission DCA_n_4
# desired LIVE failed for pilot Stinger on mission CAS_d_4
# desired LIVE failed for pilot Stinger on mission ISR_d_2
# desired LIVE failed for pilot Jester on mission SDEAD_d_2
# desired LIVE failed for pilot Jester on mission SDEAD_d_4
# desired LIVE failed for pilot Jester on mission AI_d_4
# desired LIVE failed for pilot Jester on mission AI_n_2
# desired LIVE failed for pilot Jester on mission AI_n_4
# desired LIVE failed for pilot Jester on mission DCA_d_2
# desired LIVE failed for pilot Jester on mission DCA_n_2
# desired LIVE failed for pilot Jester on mission CAS_n_2
# desired LIVE failed for pilot Jester on mission ISR_n_2
# desired LIVE failed for pilot Slider on mission OCA_n_4
# desired LIVE failed for pilot Hollywood on mission AI_n_2
# desired LIVE failed for pilot Cougar on mission OCA_n_4
# desired LIVE failed for pilot Charlie on mission OCA_d_4
# desired LIVE failed for pilot Charlie on mission SDEAD_n_2
# desired LIVE failed for pilot Charlie on mission AI_n_2
# desired LIVE failed for pilot Charlie on mission DCA_n_4
# desired LIVE failed for pilot Charlie on mission ISR_n_2
# desired LIVE failed for pilot Chipper on mission OCA_d_2
# desired LIVE failed for pilot Chipper on mission SDEAD_n_2
# desired LIVE failed for pilot Chipper on mission SDEAD_n_4
# desired LIVE failed for pilot Chipper on mission AI_d_2
# desired LIVE failed for pilot Chipper on mission DCA_d_2
# desired LIVE failed for pilot Chipper on mission CAS_d_4
# desired LIVE failed for pilot Kenny on mission OCA_d_2
# desired LIVE failed for pilot Kenny on mission OCA_d_4
# desired LIVE failed for pilot Kenny on mission SDEAD_d_2
# desired LIVE failed for pilot Kenny on mission SDEAD_n_2
# desired LIVE failed for pilot Kenny on mission AI_d_2
# desired LIVE failed for pilot Kenny on mission AI_n_2
# desired LIVE failed for pilot Kenny on mission CAS_d_4
# min LIVE failed for pilot Viper on mission OCA_n_4
# min LIVE failed for pilot Viper on mission CAS_n_4
# min LIVE failed for pilot Sundown on mission OCA_n_4
# min LIVE failed for pilot Sundown on mission AI_n_4
# min LIVE failed for pilot Slider on mission DCA_d_4
# min LIVE failed for pilot Charlie on mission AI_n_4
# min LIVE failed for pilot Chipper on mission OCA_n_4
# min LIVE failed for pilot Chipper on mission SDEAD_n_4
# min LIVE failed for pilot Kenny on mission OCA_d_4
# min LIVE failed for pilot Zone on mission DCA_n_4
# desired LIVE failed for pilot Iceman on mission DCA_n_2
# desired LIVE failed for pilot Viper on mission OCA_n_4
# desired LIVE failed for pilot Viper on mission CAS_n_4
# desired LIVE failed for pilot Sundown on mission OCA_n_4
# desired LIVE failed for pilot Sundown on mission AI_n_4
# desired LIVE failed for pilot Jester on mission SDEAD_d_4
# desired LIVE failed for pilot Jester on mission DCA_n_2
# desired LIVE failed for pilot Slider on mission DCA_d_4
# desired LIVE failed for pilot Hollywood on mission OCA_d_4
# desired LIVE failed for pilot Wolfman on mission DCA_n_2
# desired LIVE failed for pilot Charlie on mission AI_n_4
# desired LIVE failed for pilot Chipper on mission OCA_n_4
# desired LIVE failed for pilot Chipper on mission SDEAD_n_4
# desired LIVE failed for pilot Kenny on mission OCA_d_4
# desired LIVE failed for pilot Loggins on mission ISR_d_2
# desired LIVE failed for pilot Zone on mission DCA_n_4
# desired LIVE failed for pilot Zone on mission CAS_n_2
# min LIVE failed for pilot Stinger on mission SDEAD_n_4
# min LIVE failed for pilot Chipper on mission SDEAD_n_4
# min LIVE failed for pilot Chipper on mission AI_n_4
# min LIVE failed for pilot Chipper on mission CAS_d_4
# min LIVE failed for pilot Kenny on mission SDEAD_n_4
# min LIVE failed for pilot Danger on mission CAS_n_4
# desired LIVE failed for pilot Maverick on mission ISR_n_2
# desired LIVE failed for pilot Sundown on mission CAS_d_2
# desired LIVE failed for pilot Sundown on mission CAS_n_2
# desired LIVE failed for pilot Stinger on mission SDEAD_n_4
# desired LIVE failed for pilot Jester on mission DCA_d_2
# desired LIVE failed for pilot Slider on mission AI_n_2
# desired LIVE failed for pilot Slider on mission CAS_d_2
# desired LIVE failed for pilot Cougar on mission DCA_n_2
# desired LIVE failed for pilot Wolfman on mission OCA_n_2
# desired LIVE failed for pilot Charlie on mission DCA_d_4
# desired LIVE failed for pilot Chipper on mission SDEAD_n_2
# desired LIVE failed for pilot Chipper on mission SDEAD_n_4
# desired LIVE failed for pilot Chipper on mission AI_n_4
# desired LIVE failed for pilot Chipper on mission CAS_d_4
# desired LIVE failed for pilot Kenny on mission SDEAD_n_4
# desired LIVE failed for pilot Danger on mission CAS_n_4
# min LIVE failed for pilot Sundown on mission OCA_d_4
# min LIVE failed for pilot Stinger on mission OCA_n_4
# min LIVE failed for pilot Stinger on mission DCA_n_4
# min LIVE failed for pilot Jester on mission OCA_n_4
# min LIVE failed for pilot Slider on mission DCA_n_4
# min LIVE failed for pilot Hollywood on mission OCA_n_4
# min LIVE failed for pilot Hollywood on mission AI_n_4
# min LIVE failed for pilot Hollywood on mission DCA_n_4
# min LIVE failed for pilot Kenny on mission OCA_d_4
# min LIVE failed for pilot Loggins on mission SDEAD_n_4
# min LIVE failed for pilot Loggins on mission AI_n_4
# desired LIVE failed for pilot Maverick on mission AI_n_2
# desired LIVE failed for pilot Iceman on mission SDEAD_n_2
# desired LIVE failed for pilot Iceman on mission AI_n_2
# desired LIVE failed for pilot Iceman on mission DCA_n_2
# desired LIVE failed for pilot Iceman on mission ISR_n_2
# desired LIVE failed for pilot Sundown on mission OCA_d_4
# desired LIVE failed for pilot Sundown on mission CAS_d_2
# desired LIVE failed for pilot Stinger on mission OCA_n_4
# desired LIVE failed for pilot Stinger on mission AI_n_2
# desired LIVE failed for pilot Stinger on mission DCA_n_4
# desired LIVE failed for pilot Jester on mission OCA_n_4
# desired LIVE failed for pilot Jester on mission CAS_d_2
# desired LIVE failed for pilot Slider on mission DCA_n_4
# desired LIVE failed for pilot Hollywood on mission OCA_n_4
# desired LIVE failed for pilot Hollywood on mission SDEAD_n_2
# desired LIVE failed for pilot Hollywood on mission AI_n_4
# desired LIVE failed for pilot Hollywood on mission DCA_n_4
# desired LIVE failed for pilot Chipper on mission SDEAD_n_2
# desired LIVE failed for pilot Kenny on mission OCA_d_4
# desired LIVE failed for pilot Loggins on mission SDEAD_n_4
# desired LIVE failed for pilot Loggins on mission AI_n_4
# desired LIVE failed for pilot Zone on mission AI_n_2
# sim missions:
# min SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Sundown on mission DCA_d_4
# desired SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Jester on mission OCA_n_4
# desired SIM failed for pilot Jester on mission AI_n_4
# desired SIM failed for pilot Jester on mission DCA_n_4
# desired SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Slider on mission OCA_d_4
# desired SIM failed for pilot Slider on mission AI_n_4
# desired SIM failed for pilot Slider on mission DCA_d_4
# desired SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Chipper on mission SDEAD_n_2
# desired SIM failed for pilot Chipper on mission DCA_n_4
# desired SIM failed for pilot Kenny on mission CAS_d_4
# min SIM failed for pilot Jester on mission OCA_n_4
# min SIM failed for pilot Jester on mission SDEAD_d_2
# min SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Sundown on mission OCA_d_4
# desired SIM failed for pilot Sundown on mission SDEAD_n_4
# desired SIM failed for pilot Sundown on mission AI_d_4
# desired SIM failed for pilot Sundown on mission AI_n_4
# desired SIM failed for pilot Sundown on mission CAS_n_4
# desired SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Jester on mission OCA_n_4
# desired SIM failed for pilot Jester on mission SDEAD_d_2
# desired SIM failed for pilot Jester on mission SDEAD_d_4
# desired SIM failed for pilot Jester on mission SDEAD_n_4
# desired SIM failed for pilot Jester on mission AI_d_4
# desired SIM failed for pilot Jester on mission AI_n_4
# desired SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Slider on mission OCA_d_4
# desired SIM failed for pilot Slider on mission SDEAD_n_4
# desired SIM failed for pilot Slider on mission AI_n_4
# desired SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Charlie on mission OCA_d_4
# desired SIM failed for pilot Charlie on mission OCA_n_4
# desired SIM failed for pilot Charlie on mission AI_n_4
# desired SIM failed for pilot Charlie on mission CAS_d_4
# desired SIM failed for pilot Kenny on mission AI_n_4
# desired SIM failed for pilot Kenny on mission DCA_n_4
# desired SIM failed for pilot Kenny on mission CAS_d_4
# desired SIM failed for pilot Loggins on mission OCA_n_4
# desired SIM failed for pilot Loggins on mission SDEAD_d_4
# desired SIM failed for pilot Loggins on mission AI_n_4
# desired SIM failed for pilot Loggins on mission DCA_d_4
# min SIM failed for pilot Jester on mission SDEAD_n_4
# min SIM failed for pilot Jester on mission AI_n_4
# min SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Sundown on mission AI_n_4
# desired SIM failed for pilot Sundown on mission DCA_d_4
# desired SIM failed for pilot Sundown on mission CAS_d_4
# desired SIM failed for pilot Stinger on mission CAS_d_4
# desired SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Jester on mission SDEAD_n_4
# desired SIM failed for pilot Jester on mission AI_n_4
# desired SIM failed for pilot Jester on mission DCA_d_4
# desired SIM failed for pilot Jester on mission CAS_d_4
# desired SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Slider on mission OCA_n_4
# desired SIM failed for pilot Slider on mission SDEAD_d_4
# desired SIM failed for pilot Slider on mission SDEAD_n_4
# desired SIM failed for pilot Slider on mission AI_n_4
# desired SIM failed for pilot Slider on mission DCA_d_4
# desired SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Charlie on mission SDEAD_n_4
# desired SIM failed for pilot Charlie on mission AI_n_4
# desired SIM failed for pilot Charlie on mission DCA_d_4
# desired SIM failed for pilot Chipper on mission OCA_n_4
# desired SIM failed for pilot Chipper on mission AI_d_4
# desired SIM failed for pilot Kenny on mission DCA_d_4
# desired SIM failed for pilot Kenny on mission DCA_n_4
# desired SIM failed for pilot Loggins on mission CAS_n_4
# min SIM failed for pilot Jester on mission AI_d_4
# min SIM failed for pilot Chipper on mission AI_d_2
# desired SIM failed for pilot Sundown on mission AI_d_4
# desired SIM failed for pilot Sundown on mission AI_n_4
# desired SIM failed for pilot Sundown on mission CAS_n_4
# desired SIM failed for pilot Stinger on mission OCA_n_4
# desired SIM failed for pilot Stinger on mission AI_n_4
# desired SIM failed for pilot Stinger on mission CAS_n_4
# desired SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Jester on mission OCA_n_4
# desired SIM failed for pilot Jester on mission SDEAD_d_4
# desired SIM failed for pilot Jester on mission SDEAD_n_4
# desired SIM failed for pilot Jester on mission AI_d_4
# desired SIM failed for pilot Jester on mission AI_n_4
# desired SIM failed for pilot Jester on mission DCA_n_4
# desired SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Slider on mission OCA_n_4
# desired SIM failed for pilot Slider on mission SDEAD_d_4
# desired SIM failed for pilot Slider on mission SDEAD_n_2
# desired SIM failed for pilot Slider on mission SDEAD_n_4
# desired SIM failed for pilot Slider on mission DCA_d_4
# desired SIM failed for pilot Slider on mission DCA_n_4
# desired SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Charlie on mission OCA_d_4
# desired SIM failed for pilot Charlie on mission OCA_n_4
# desired SIM failed for pilot Charlie on mission AI_n_4
# desired SIM failed for pilot Chipper on mission OCA_n_4
# desired SIM failed for pilot Chipper on mission SDEAD_n_4
# desired SIM failed for pilot Chipper on mission AI_d_2
# desired SIM failed for pilot Chipper on mission DCA_n_4
# desired SIM failed for pilot Chipper on mission CAS_d_4
# desired SIM failed for pilot Chipper on mission CAS_n_4
# ...
# desired SIM failed for pilot Charlie on mission CAS_n_4
# desired SIM failed for pilot Chipper on mission SDEAD_n_2
# desired SIM failed for pilot Chipper on mission AI_d_4
# desired SIM failed for pilot Chipper on mission CAS_n_4
# desired SIM failed for pilot Kenny on mission OCA_d_4
# desired SIM failed for pilot Kenny on mission SDEAD_n_4
# desired SIM failed for pilot Loggins on mission OCA_d_4
# desired SIM failed for pilot Loggins on mission OCA_n_4
# desired SIM failed for pilot Loggins on mission SDEAD_d_4
# min SIM failed for pilot Iceman on mission OCA_d_2
# min SIM failed for pilot Chipper on mission AI_d_4
# min SIM failed for pilot Kenny on mission DCA_n_4
# desired SIM failed for pilot Iceman on mission OCA_d_2
# desired SIM failed for pilot Sundown on mission AI_d_4
# desired SIM failed for pilot Sundown on mission DCA_d_4
# desired SIM failed for pilot Sundown on mission CAS_n_4
# desired SIM failed for pilot Stinger on mission OCA_n_4
# desired SIM failed for pilot Jester on mission OCA_n_4
# desired SIM failed for pilot Jester on mission DCA_n_4
# desired SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Slider on mission DCA_d_4
# desired SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Charlie on mission OCA_d_4
# desired SIM failed for pilot Charlie on mission AI_n_4
# desired SIM failed for pilot Charlie on mission DCA_n_4
# desired SIM failed for pilot Charlie on mission CAS_n_4
# desired SIM failed for pilot Chipper on mission SDEAD_d_4
# desired SIM failed for pilot Chipper on mission AI_d_4
# desired SIM failed for pilot Chipper on mission AI_n_4
# desired SIM failed for pilot Chipper on mission DCA_n_4
# desired SIM failed for pilot Chipper on mission CAS_d_4
# desired SIM failed for pilot Chipper on mission CAS_n_4
# desired SIM failed for pilot Kenny on mission SDEAD_n_4
# desired SIM failed for pilot Kenny on mission AI_n_4
# desired SIM failed for pilot Kenny on mission DCA_n_4
# desired SIM failed for pilot Kenny on mission CAS_n_4
# desired SIM failed for pilot Loggins on mission CAS_n_4
# min SIM failed for pilot Slider on mission SDEAD_d_4
# min SIM failed for pilot Merlin on mission SDEAD_d_4
# desired SIM failed for pilot Sundown on mission SDEAD_d_4
# desired SIM failed for pilot Sundown on mission AI_n_4
# desired SIM failed for pilot Sundown on mission DCA_d_4
# desired SIM failed for pilot Stinger on mission SDEAD_n_4
# desired SIM failed for pilot Stinger on mission CAS_n_4
# desired SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Jester on mission OCA_n_4
# desired SIM failed for pilot Jester on mission SDEAD_n_4
# desired SIM failed for pilot Jester on mission AI_n_4
# desired SIM failed for pilot Slider on mission OCA_n_4
# desired SIM failed for pilot Slider on mission SDEAD_d_4
# desired SIM failed for pilot Slider on mission SDEAD_n_4
# desired SIM failed for pilot Slider on mission AI_n_4
# desired SIM failed for pilot Slider on mission DCA_d_4
# desired SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Merlin on mission SDEAD_d_4
# desired SIM failed for pilot Charlie on mission OCA_d_4
# desired SIM failed for pilot Charlie on mission SDEAD_n_4
# desired SIM failed for pilot Chipper on mission OCA_n_4
# desired SIM failed for pilot Chipper on mission CAS_d_4
# desired SIM failed for pilot Kenny on mission OCA_d_4
# desired SIM failed for pilot Kenny on mission SDEAD_n_4
# desired SIM failed for pilot Kenny on mission AI_n_4
# desired SIM failed for pilot Loggins on mission OCA_d_4
# desired SIM failed for pilot Loggins on mission OCA_n_4
# desired SIM failed for pilot Loggins on mission SDEAD_d_4
# desired SIM failed for pilot Loggins on mission AI_n_4
# desired SIM failed for pilot Loggins on mission CAS_n_4
# min SIM failed for pilot Sundown on mission AI_n_4
# min SIM failed for pilot Sundown on mission CAS_d_4
# min SIM failed for pilot Jester on mission OCA_d_4
# min SIM failed for pilot Jester on mission SDEAD_n_4
# min SIM failed for pilot Jester on mission AI_n_4
# min SIM failed for pilot Jester on mission DCA_n_4
# min SIM failed for pilot Chipper on mission OCA_n_4
# min SIM failed for pilot Loggins on mission SDEAD_n_4
# desired SIM failed for pilot Sundown on mission OCA_d_4
# desired SIM failed for pilot Sundown on mission OCA_n_4
# desired SIM failed for pilot Sundown on mission SDEAD_d_4
# desired SIM failed for pilot Sundown on mission AI_d_4
# desired SIM failed for pilot Sundown on mission AI_n_4
# desired SIM failed for pilot Sundown on mission DCA_d_4
# desired SIM failed for pilot Sundown on mission CAS_d_4
# desired SIM failed for pilot Stinger on mission AI_d_4
# desired SIM failed for pilot Stinger on mission DCA_d_4
# desired SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Jester on mission SDEAD_n_2
# desired SIM failed for pilot Jester on mission SDEAD_n_4
# desired SIM failed for pilot Jester on mission AI_d_4
# desired SIM failed for pilot Jester on mission AI_n_4
# desired SIM failed for pilot Jester on mission DCA_d_4
# desired SIM failed for pilot Jester on mission DCA_n_4
# desired SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Slider on mission OCA_d_4
# desired SIM failed for pilot Slider on mission OCA_n_4
# desired SIM failed for pilot Slider on mission SDEAD_d_4
# desired SIM failed for pilot Slider on mission SDEAD_n_4
# desired SIM failed for pilot Slider on mission AI_d_4
# desired SIM failed for pilot Slider on mission DCA_d_4
# desired SIM failed for pilot Slider on mission DCA_n_4
# desired SIM failed for pilot Slider on mission CAS_d_4
# desired SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Charlie on mission OCA_d_4
# desired SIM failed for pilot Charlie on mission SDEAD_d_4
# desired SIM failed for pilot Charlie on mission SDEAD_n_4
# desired SIM failed for pilot Charlie on mission DCA_n_4
# desired SIM failed for pilot Chipper on mission OCA_n_4
# desired SIM failed for pilot Chipper on mission SDEAD_d_4
# desired SIM failed for pilot Chipper on mission AI_d_4
# desired SIM failed for pilot Chipper on mission AI_n_4
# desired SIM failed for pilot Chipper on mission DCA_d_4
# desired SIM failed for pilot Chipper on mission DCA_n_4
# desired SIM failed for pilot Kenny on mission OCA_d_4
# desired SIM failed for pilot Kenny on mission OCA_n_4
# desired SIM failed for pilot Kenny on mission SDEAD_n_4
# desired SIM failed for pilot Kenny on mission AI_n_4
# desired SIM failed for pilot Kenny on mission DCA_d_4
# desired SIM failed for pilot Kenny on mission CAS_d_4
# desired SIM failed for pilot Loggins on mission SDEAD_n_4
# desired SIM failed for pilot Loggins on mission DCA_n_4
# min SIM failed for pilot Sundown on mission AI_n_4
# min SIM failed for pilot Loggins on mission DCA_n_4
# min SIM failed for pilot Loggins on mission ISR_d_2
# desired SIM failed for pilot Sundown on mission OCA_d_4
# desired SIM failed for pilot Sundown on mission SDEAD_n_4
# desired SIM failed for pilot Sundown on mission AI_d_4
# desired SIM failed for pilot Sundown on mission AI_n_4
# desired SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Jester on mission OCA_n_4
# desired SIM failed for pilot Jester on mission AI_n_4
# desired SIM failed for pilot Jester on mission DCA_d_4
# desired SIM failed for pilot Jester on mission DCA_n_4
# desired SIM failed for pilot Slider on mission OCA_n_4
# desired SIM failed for pilot Slider on mission SDEAD_d_4
# desired SIM failed for pilot Slider on mission SDEAD_n_4
# desired SIM failed for pilot Slider on mission AI_n_4
# desired SIM failed for pilot Slider on mission DCA_n_4
# desired SIM failed for pilot Charlie on mission OCA_d_4
# desired SIM failed for pilot Charlie on mission DCA_n_4
# desired SIM failed for pilot Charlie on mission CAS_d_4
# desired SIM failed for pilot Charlie on mission CAS_n_4
# desired SIM failed for pilot Chipper on mission OCA_n_4
# desired SIM failed for pilot Chipper on mission AI_d_4
# desired SIM failed for pilot Chipper on mission AI_n_4
# desired SIM failed for pilot Chipper on mission CAS_d_4
# desired SIM failed for pilot Kenny on mission SDEAD_d_4
# desired SIM failed for pilot Kenny on mission DCA_d_4
# desired SIM failed for pilot Kenny on mission DCA_n_4
# desired SIM failed for pilot Kenny on mission CAS_d_4
# desired SIM failed for pilot Loggins on mission DCA_n_4
# desired SIM failed for pilot Loggins on mission ISR_d_2
# min SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Sundown on mission DCA_d_4
# desired SIM failed for pilot Sundown on mission DCA_n_4
# desired SIM failed for pilot Stinger on mission OCA_n_4
# desired SIM failed for pilot Stinger on mission SDEAD_n_4
# desired SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Jester on mission OCA_n_4
# desired SIM failed for pilot Jester on mission AI_n_4
# desired SIM failed for pilot Jester on mission DCA_d_4
# desired SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Slider on mission DCA_d_4
# desired SIM failed for pilot Slider on mission DCA_n_4
# desired SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Charlie on mission CAS_d_4
# desired SIM failed for pilot Chipper on mission AI_d_4
# desired SIM failed for pilot Chipper on mission DCA_n_4
# desired SIM failed for pilot Chipper on mission CAS_d_4
# desired SIM failed for pilot Chipper on mission CAS_n_4
# desired SIM failed for pilot Kenny on mission DCA_n_4
# desired SIM failed for pilot Kenny on mission CAS_n_4
# min SIM failed for pilot Goose on mission SDEAD_d_2
# min SIM failed for pilot Charlie on mission OCA_d_4
# min SIM failed for pilot Loggins on mission SDEAD_d_4
# desired SIM failed for pilot Goose on mission SDEAD_d_2
# desired SIM failed for pilot Sundown on mission OCA_d_4
# desired SIM failed for pilot Sundown on mission OCA_n_4
# desired SIM failed for pilot Sundown on mission SDEAD_n_4
# desired SIM failed for pilot Sundown on mission AI_n_4
# desired SIM failed for pilot Sundown on mission DCA_d_4
# desired SIM failed for pilot Stinger on mission OCA_n_4
# desired SIM failed for pilot Stinger on mission DCA_d_4
# desired SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Jester on mission OCA_n_4
# desired SIM failed for pilot Jester on mission SDEAD_d_4
# desired SIM failed for pilot Jester on mission AI_d_4
# desired SIM failed for pilot Jester on mission AI_n_4
# desired SIM failed for pilot Jester on mission DCA_n_4
# desired SIM failed for pilot Jester on mission CAS_d_4
# desired SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Slider on mission OCA_n_4
# desired SIM failed for pilot Slider on mission SDEAD_d_4
# desired SIM failed for pilot Slider on mission SDEAD_n_4
# desired SIM failed for pilot Slider on mission AI_n_4
# desired SIM failed for pilot Slider on mission DCA_d_4
# desired SIM failed for pilot Slider on mission DCA_n_4
# desired SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Charlie on mission OCA_d_4
# desired SIM failed for pilot Charlie on mission SDEAD_d_4
# desired SIM failed for pilot Charlie on mission SDEAD_n_4
# desired SIM failed for pilot Charlie on mission AI_n_4
# desired SIM failed for pilot Charlie on mission DCA_d_4
# desired SIM failed for pilot Charlie on mission DCA_n_4
# desired SIM failed for pilot Charlie on mission CAS_d_4
# desired SIM failed for pilot Charlie on mission CAS_n_2
# desired SIM failed for pilot Chipper on mission OCA_d_4
# desired SIM failed for pilot Chipper on mission OCA_n_4
# desired SIM failed for pilot Chipper on mission SDEAD_n_4
# desired SIM failed for pilot Kenny on mission OCA_n_4
# desired SIM failed for pilot Kenny on mission SDEAD_n_4
# desired SIM failed for pilot Kenny on mission AI_n_4
# desired SIM failed for pilot Loggins on mission SDEAD_d_4
# desired SIM failed for pilot Loggins on mission AI_n_4
# min SIM failed for pilot Jester on mission OCA_n_4
# min SIM failed for pilot Loggins on mission DCA_d_4
# desired SIM failed for pilot Sundown on mission OCA_n_4
# desired SIM failed for pilot Sundown on mission SDEAD_n_4
# desired SIM failed for pilot Sundown on mission AI_d_4
# desired SIM failed for pilot Sundown on mission AI_n_4
# desired SIM failed for pilot Sundown on mission DCA_d_4
# desired SIM failed for pilot Sundown on mission CAS_d_4
# desired SIM failed for pilot Sundown on mission CAS_n_4
# desired SIM failed for pilot Stinger on mission SDEAD_d_4
# desired SIM failed for pilot Stinger on mission SDEAD_n_4
# desired SIM failed for pilot Stinger on mission AI_d_4
# desired SIM failed for pilot Stinger on mission DCA_d_4
# desired SIM failed for pilot Jester on mission OCA_n_4
# desired SIM failed for pilot Jester on mission SDEAD_n_4
# desired SIM failed for pilot Jester on mission AI_d_4
# desired SIM failed for pilot Jester on mission DCA_d_4
# desired SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Slider on mission OCA_n_4
# desired SIM failed for pilot Slider on mission SDEAD_d_4
# desired SIM failed for pilot Slider on mission SDEAD_n_4
# desired SIM failed for pilot Slider on mission DCA_d_4
# desired SIM failed for pilot Slider on mission DCA_n_4
# desired SIM failed for pilot Slider on mission CAS_n_4
# desired SIM failed for pilot Charlie on mission OCA_d_4
# desired SIM failed for pilot Chipper on mission OCA_n_4
# desired SIM failed for pilot Chipper on mission SDEAD_n_4
# desired SIM failed for pilot Chipper on mission AI_d_4
# desired SIM failed for pilot Kenny on mission DCA_d_4
# desired SIM failed for pilot Loggins on mission AI_n_4
# desired SIM failed for pilot Loggins on mission DCA_d_4
# desired SIM failed for pilot Loggins on mission CAS_d_4
# desired SIM failed for pilot Loggins on mission CAS_n_4
# min SIM failed for pilot Maverick on mission AI_d_2
# min SIM failed for pilot Jester on mission OCA_n_4
# min SIM failed for pilot Kenny on mission OCA_d_2
# min SIM failed for pilot Kenny on mission SDEAD_n_4
# min SIM failed for pilot Kenny on mission AI_n_4
# min SIM failed for pilot Kenny on mission CAS_d_2
# desired SIM failed for pilot Maverick on mission AI_d_2
# desired SIM failed for pilot Sundown on mission OCA_d_4
# desired SIM failed for pilot Sundown on mission OCA_n_4
# desired SIM failed for pilot Sundown on mission SDEAD_n_4
# desired SIM failed for pilot Sundown on mission AI_d_4
# desired SIM failed for pilot Sundown on mission AI_n_4
# desired SIM failed for pilot Sundown on mission CAS_n_4
# desired SIM failed for pilot Stinger on mission SDEAD_n_4
# desired SIM failed for pilot Stinger on mission AI_n_4
# desired SIM failed for pilot Stinger on mission DCA_d_4
# desired SIM failed for pilot Stinger on mission DCA_n_4
# desired SIM failed for pilot Stinger on mission CAS_n_4
# desired SIM failed for pilot Jester on mission OCA_d_4
# desired SIM failed for pilot Jester on mission OCA_n_4
# desired SIM failed for pilot Jester on mission SDEAD_n_4
# desired SIM failed for pilot Jester on mission AI_d_4
# desired SIM failed for pilot Jester on mission AI_n_4
# desired SIM failed for pilot Jester on mission DCA_n_4
# desired SIM failed for pilot Jester on mission CAS_n_4
# desired SIM failed for pilot Slider on mission SDEAD_d_4
# desired SIM failed for pilot Slider on mission SDEAD_n_4
# desired SIM failed for pilot Slider on mission DCA_d_4
# desired SIM failed for pilot Charlie on mission OCA_d_4
# desired SIM failed for pilot Charlie on mission OCA_n_4
# desired SIM failed for pilot Charlie on mission DCA_n_4
# desired SIM failed for pilot Charlie on mission CAS_d_4
# desired SIM failed for pilot Charlie on mission CAS_n_4
# desired SIM failed for pilot Chipper on mission SDEAD_n_4
# desired SIM failed for pilot Chipper on mission DCA_n_4
# desired SIM failed for pilot Kenny on mission OCA_d_2
# desired SIM failed for pilot Kenny on mission OCA_d_4
# desired SIM failed for pilot Kenny on mission SDEAD_d_4
# desired SIM failed for pilot Kenny on mission SDEAD_n_4
# desired SIM failed for pilot Kenny on mission AI_n_4
# desired SIM failed for pilot Kenny on mission DCA_d_4
# desired SIM failed for pilot Kenny on mission CAS_d_2
# desired SIM failed for pilot Kenny on mission CAS_d_4
# desired SIM failed for pilot Kenny on mission CAS_n_4

# %%
pilotFL = list()
for p in P:
    pilotFL.append(P[p][4])
print(no_sorties_live)
print(sum(no_sorties_live))
print(no_sorties_sim)
print(sum(no_sorties_sim))
print(pilotFL)
#for i in range(len(no_sorties_live)):
 #   print(no_sorties_live[i]+(no_sorties_sim[i]))
# Out:
# [97, 89, 86, 100, 83, 88, 82, 87, 93, 89, 92, 91, 95, 90, 89, 92, 93, 93]
# 1629
# [65, 64, 70, 65, 90, 88, 84, 95, 62, 69, 67, 64, 84, 94, 85, 94, 66, 68]
# 1374
# [4, 4, 2, 2, 0, 0, 0, 0, 4, 4, 2, 2, 0, 0, 0, 0, 4, 4]

# %%
comp = []
for i in range(len(data)):
    print(data[i])
    print(min(data[i]))
    comp.append(min(data[i]))
# Out:
# [  15   11 1716   17   13 1455]
# 11
# [  12    8 1687   17   12 1418]
# 8
# [  14    9 1704   16   10 1399]
# 9
# [  11    7 1748   16   10 1389]
# 7
# [  12   10 1682   14   10 1384]
# 10
# [  16   12 1712   15    9 1412]
# 9
# [  12    5 1645   16   10 1402]
# 5
# [  14   10 1685   17   10 1404]
# 10
# [  12    9 1698   15   11 1451]
# 9
# [  12    9 1648   13   10 1358]
# 9
# [  11    6 1676   15   10 1408]
# 6
# [  15    6 1663   14    9 1399]
# 6
# [  13    9 1692   16   12 1449]
# 9
# [  15    4 1696   14   10 1402]
# 4
# [  12    8 1666   15   10 1421]
# 8
# [  13   11 1692   15   10 1437]
# 10
# [  15   11 1709   13    9 1354]
# 9
# [  14   10 1659   16   11 1411]
# 10
# [  15   10 1672   15    9 1380]
# 9
# [  15   10 1701   13    9 1402]
# 9
# [  13    9 1633   13    8 1373]
# 8
# [  15   12 1667   16    9 1408]
# 9
# [  13    5 1675   15    9 1456]
# 5
# [  14    8 1704   16    9 1407]
# 8
# [  12    8 1656   14   10 1374]
# 8
# [  11    8 1670   16   11 1401]
# 8
# [  11    8 1602   17   11 1445]
# 8
# [  11    6 1670   15    9 1369]
# 6
# [  14    7 1702   16   10 1413]
# 7
# [  11    7 1629   15   10 1374]
# 7

# %%
print(sum(comp)/len(comp))
# Out:
# 8.033333333333333

# %%
avgs = []
for i in range(len(data)):
    print(min(data[i]))
    avgs.append(min(data[i]))
# Out:
# 11
# 8
# 9
# 7
# 10
# 9
# 5
# 10
# 9
# 9
# 6
# 6
# 9
# 4
# 8
# 10
# 9
# 10
# 9
# 9
# 8
# 9
# 5
# 8
# 8
# 8
# 8
# 6
# 7
# 7

# %%
print(sum(avgs)/len(avgs))
# Out:
# 8.033333333333333

# %%
run_data = []
relative = []
for file in glob.glob('*_data.txt'):
    with open(file) as f:
        a = json.load(f)
        run_data.append(a["FHR_cummulative"])
        relative.append(a['regen'])
print(run_data[0][1])
# Out:
# 9.0

# %%
for i in range(len(relative)):
    plt.plot(relative[i])
plt.axhline(y=1, color='g', linestyle='-')
plt.axhline(y=1.05, color='g', linestyle='dashdot')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
bound = []

line_max = []
line_min = []
line_avg = []
#for i in range(30):
   # for j in range(len(run_data)):
        #print(run_data[j][i])

# %%
bound = []

line = []
for j in range(len(run_data)):
    line.append(max(run_data[j]))
print(line)
bound.append(line)
#plt.plot(bound[0])
# Out:
# [2574.0, 2530.5, 2556.0, 2622.0, 2523.0, 2568.0, 2467.5, 2527.5, 2547.0, 2472.0, 2514.0, 2494.5, 2538.0, 2544.0, 2499.0, 2538.0, 2563.5, 2488.5, 2508.0, 2551.5, 2449.5, 2500.5, 2512.5, 2556.0, 2484.0, 2505.0, 2403.0, 2505.0, 2553.0, 2443.5]

# %%
fig, ax = plt.subplots()
boxes = [data[0:30,0], data[0:30,1], data[0:30,3], data[0:30,4]]
bp = ax.boxplot(boxes, patch_artist=True)
ax.set(xlabel='CT'.format('Arial'))
ax.set(ylabel='minimum completion'.format('Arial'))
ax.set_title('Dynamic rescheduling'.format('Arial'))
ax.set_xticklabels(['min_live', 'des_live', 'min_sim', 'des_sim', f'{len(data)}'])
for box in bp['boxes']:
    box.set( color='k', linewidth=0.5)
    box.set( facecolor = 'w' )

for flier in bp['fliers']:
    flier.set(marker='o', color='r')#, alpha=0.5
fig.savefig('box.jpg', dpi=300)

# %%
plt.plot(data[:,2]/max(data[:,2]), label='sorties executed')
plt.plot(data[:,0]/max(data[:,0]), c='r', label='min_CT completion')
plt.title('number of sorties required')
plt.legend()
plt.savefig('sorties_normalized.jpg', dpi=300)

# %%
covariance = np.cov(data[:,2]/max(data[:,2]), (data[:,0]/10))
r_pearson = pearsonr(data[:,2], data[:,0])
print(r_pearson[0]) #pearson r
print(r_pearson[1]) #significance for pearson r
# Out:
# 0.38653094685545064
# 0.034862641319835734

# %%
plt.hist(data[:,0], histtype='step')
plt.show()

# %%
plt.hist(data[0:70,0], histtype='step')
plt.show()
